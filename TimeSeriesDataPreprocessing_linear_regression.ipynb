# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt 
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
#IMPORTANT : import the DataPreprocessing class
from DataPreprocessing import DataPreprocessing

# %%
#The first step is to instanciate the DataPreprocessing class as follow
DP = DataPreprocessing()

# %%
# Loading The Data of Stations.
df1 = pd.read_csv('Station1.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df2 = pd.read_csv('Station2.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df3 = pd.read_csv('Station3.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df4 = pd.read_csv('Station4.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df5 = pd.read_csv('Station5.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df6 = pd.read_csv('Station6.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df7 = pd.read_csv('Station7.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df8 = pd.read_csv('Station8.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df9 = pd.read_csv('Station9.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df10 = pd.read_csv('Station10.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df11 = pd.read_csv('Station11.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df12 = pd.read_csv('Station12.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df13 = pd.read_csv('Station13.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df14 = pd.read_csv('Station14.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df15 = pd.read_csv('Station15.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df16 = pd.read_csv('Station16.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df17 = pd.read_csv('Station17.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df18 = pd.read_csv('Station18.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df19 = pd.read_csv('Station19.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df20 = pd.read_csv('Station20.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df21 = pd.read_csv('Station21.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df22 = pd.read_csv('Station22.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df23 = pd.read_csv('Station23.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df24 = pd.read_csv('Station24.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df25 = pd.read_csv('Station25.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df26 = pd.read_csv('Station26.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df27 = pd.read_csv('Station27.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df28 = pd.read_csv('Station28.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df29 = pd.read_csv('Station29.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df30 = pd.read_csv('Station30.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df31 = pd.read_csv('Station31.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df32 = pd.read_csv('Station32.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df33 = pd.read_csv('Station33.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df34 = pd.read_csv('Station34.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
df35 = pd.read_csv('Station35.csv', names=['Index', 'Station', 'Year', 'Month', 'Day','Raifall'])
#df1

# %%
#d1=df1[df1['Year'] == 1970] #
#d1

# %%
#Computing Monthly_Mean_Rainfall for every Year of Station1= Dhaka
for Year in range(1999,2017):
    Yeardf1 = df1[df1['Year'] == Year]
    for Month in range(1,13):
        print('Year = ',Year, 'Month= ',Month,' MonthlymeanRainfall = ',Yeardf1[Yeardf1['Month'] == Month]['Raifall'].mean())
# Out:
# Year =  1999 Month=  1  MonthlymeanRainfall =  0.0
# Year =  1999 Month=  2  MonthlymeanRainfall =  0.0
# Year =  1999 Month=  3  MonthlymeanRainfall =  0.0
# Year =  1999 Month=  4  MonthlymeanRainfall =  0.6774193548387096
# Year =  1999 Month=  5  MonthlymeanRainfall =  13.806451612903226
# Year =  1999 Month=  6  MonthlymeanRainfall =  11.225806451612904
# Year =  1999 Month=  7  MonthlymeanRainfall =  17.838709677419356
# Year =  1999 Month=  8  MonthlymeanRainfall =  9.096774193548388
# Year =  1999 Month=  9  MonthlymeanRainfall =  11.64516129032258
# Year =  1999 Month=  10  MonthlymeanRainfall =  11.870967741935484
# Year =  1999 Month=  11  MonthlymeanRainfall =  0.41935483870967744
# Year =  1999 Month=  12  MonthlymeanRainfall =  0.0
# Year =  2000 Month=  1  MonthlymeanRainfall =  0.41935483870967744
# Year =  2000 Month=  2  MonthlymeanRainfall =  1.4193548387096775
# Year =  2000 Month=  3  MonthlymeanRainfall =  5.548387096774194
# ...

# %%
A=[]
for Year in range(1999,2017):
    Yeardf1 = df1[df1['Year'] == Year]
    for Month in range(1,13):
        #print('Year = ',Year, 'Month= ',Month,' MonthlymeanRainfall = ',Yeardf1[Yeardf1['Month'] == Month]['Raifall'].mean())
    
        A.append(Yeardf1[Yeardf1['Month'] == Month]['Raifall'].mean())   
A
# Out:
# [0.0,
#  0.0,
#  0.0,
#  0.6774193548387096,
#  13.806451612903226,
#  11.225806451612904,
#  17.838709677419356,
#  9.096774193548388,
#  11.64516129032258,
#  11.870967741935484,
#  0.41935483870967744,
#  0.0,
#  0.41935483870967744,
#  1.4193548387096775,
#  5.548387096774194,
#  6.096774193548387,
#  19.612903225806452,
#  5.32258064516129,
#  6.354838709677419,
#  11.580645161290322,
#  6.967741935483871,
#  8.96774193548387,
#  0.0,
#  0.0,
#  0.0,
#  0.03225806451612903,
#  1.064516129032258,
#  1.4838709677419355,
#  12.96774193548387,
#  12.451612903225806,
#  6.516129032258065,
#  6.612903225806452,
#  6.741935483870968,
#  5.709677419354839,
#  0.5806451612903226,
#  0.0,
#  0.7096774193548387,
#  0.12903225806451613,
#  1.6451612903225807,
#  3.5806451612903225,
#  8.774193548387096,
#  12.03225806451613,
#  14.387096774193548,
#  8.774193548387096,
#  5.032258064516129,
#  1.6774193548387097,
#  1.1612903225806452,
#  0.0,
#  0.0,
#  0.8064516129032258,
# ...

# %%
#We will only use the "Monthly_Mean_Rainfall_for_Station1" computed above
time_series_df =pd.DataFrame({'MonthlyMeanRainfallforStation1': A})
time_series_df
# Out:
#      MonthlyMeanRainfallforStation1
# 0                          0.000000
# 1                          0.000000
# 2                          0.000000
# 3                          0.677419
# 4                         13.806452
# 5                         11.225806
# 6                         17.838710
# 7                          9.096774
# 8                         11.645161
# 9                         11.870968
# 10                         0.419355
# 11                         0.000000
# 12                         0.419355
# 13                         1.419355
# 14                         5.548387
# 15                         6.096774
# 16                        19.612903
# 17                         5.322581
# 18                         6.354839
# 19                        11.580645
# 20                         6.967742
# 21                         8.967742
# 22                         0.000000
# 23                         0.000000
# 24                         0.000000
# ...

# %%
#We need to specify the column that corresponds to the time series (Rainfall) and the time horizon (40)
X, y = DP.create_dataset_in_time_series_form(entire_dataframe=time_series_df, time_series_column="MonthlyMeanRainfallforStation1", time_horizon=40)

# %%
pd.DataFrame(data=X)
#You can notice that there are 40 columns : since we want to predict $Y_{t+1}$ base on the 40 previous values of $Y_{t}$
#Take a look at line 10 and 11. $Y_{t+1}$ for line 10 is "8". This same 8 will be the 40th features of line 11
# Out:
#             0          1          2          3          4          5   \
# 0     0.000000   0.000000   0.000000   0.677419  13.806452  11.225806
# 1     0.000000   0.000000   0.677419  13.806452  11.225806  17.838710
# 2     0.000000   0.677419  13.806452  11.225806  17.838710   9.096774
# 3     0.677419  13.806452  11.225806  17.838710   9.096774  11.645161
# 4    13.806452  11.225806  17.838710   9.096774  11.645161  11.870968
# 5    11.225806  17.838710   9.096774  11.645161  11.870968   0.419355
# 6    17.838710   9.096774  11.645161  11.870968   0.419355   0.000000
# 7     9.096774  11.645161  11.870968   0.419355   0.000000   0.419355
# 8    11.645161  11.870968   0.419355   0.000000   0.419355   1.419355
# 9    11.870968   0.419355   0.000000   0.419355   1.419355   5.548387
# 10    0.419355   0.000000   0.419355   1.419355   5.548387   6.096774
# 11    0.000000   0.419355   1.419355   5.548387   6.096774  19.612903
# ...

# %%
pd.DataFrame(data=y)
#Take a look at line 10 (starting with "0" of course) : $Y_{t+1}$ is 8 in this case
# Out:
#     Y_t_plus_1
# 0     8.774194
# 0    12.032258
# 0    14.387097
# 0     8.774194
# 0     5.032258
# 0     1.677419
# 0     1.161290
# 0     0.000000
# 0     0.000000
# 0     0.806452
# 0     3.096774
# 0     3.967742
# 0     4.516129
# 0    15.258065
# 0     6.161290
# 0     6.516129
# 0     8.516129
# 0     4.322581
# 0     0.000000
# 0     1.451613
# 0     0.000000
# 0     0.000000
# 0     0.290323
# 0     5.387097
# 0     5.225806
# 0    15.354839
# 0     9.516129
# 0     6.161290
# 0    27.064516
# 0     6.709677
# ..         ...
# 0     6.838710
# 0    12.612903
# 0     5.032258
# 0     1.580645
# 0     0.000000
# 0     0.000000
# 0     0.096774
# 0     0.548387
# 0     0.129032
# 0     5.354839
# 0     5.967742
# 0    12.096774
# 0    20.096774
# 0    12.741935
# 0    11.161290
# 0     1.645161
# 0     0.000000
# 0     0.032258
# 0     0.096774
# 0     0.419355
# 0     1.774194
# 0     1.774194
# 0     6.838710
# 0     6.838710
# 0    13.064516
# 0     5.516129
# ...

# %% [markdown]
# # How to use Scikit-lean with this form of dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((132, 40), (44, 40), (132, 1), (44, 1))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm

# %%
model = LinearRegression()
#model = RandomForestRegressor()
#model = svm.SVR()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.33183911623562246

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[ 1.58693466],
#        [ 3.95196146],
#        [ 8.65230996],
#        [11.73696979],
#        [ 4.37807989],
#        [ 2.90389564],
#        [ 3.24410887],
#        [ 5.53823843],
#        [-0.15676408],
#        [ 3.19646221],
#        [ 4.08179892],
#        [ 2.30870962],
#        [ 7.70387455],
#        [ 1.83555522],
#        [ 1.19030492],
#        [11.1649851 ],
#        [ 6.80440539],
#        [11.79118775],
#        [-3.31414988],
#        [ 5.72383357],
#        [ 1.06909278],
#        [ 5.18506448],
#        [10.67722464],
#        [ 5.15490869],
#        [13.15944516],
#        [ 3.16649525],
#        [ 0.59194147],
#        [ 8.28093572],
#        [11.94858593],
#        [ 4.33630076],
#        [19.04357995],
#        [ 0.85416797],
#        [ 3.09335238],
#        [10.69437122],
#        [ 4.07204871],
#        [-2.45873157],
#        [ 5.97144651],
#        [11.12298828],
#        [10.63783726],
#        [-1.98293757],
#        [ 0.79545335],
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 5.073099767934364
